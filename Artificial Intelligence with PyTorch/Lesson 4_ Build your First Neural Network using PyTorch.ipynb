# %%
import torch
import torch.nn.functional as F
import torch.nn as nn

# %%
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(4, 3)
    self.fc2 = nn.Linear(3, 1)

  def forward(self, x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    return x
  

net = Net()
print(net)
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=3, bias=True)
#   (fc2): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
input = torch.randn(100, 1, 4)
target = torch.randint(0, 2, (100, 1, 1))
input = input.float()
target = target.float()

criterion = nn.MSELoss()
learning_rate = 0.1
num_epochs = 100
for epoch in range(num_epochs):
  losses = 0.0
  net.zero_grad()
  output = net(input)
  output = output.float()
  preds = torch.round(output)
  loss = criterion(output, target)
  losses += loss
  acc = torch.sum(preds == target)
  print("Epoch: " + str(epoch + 1) + "\nAccuracy = " + str(acc) + "\nLoss = " + str(losses) + "\n")
  losses.backward()
  for f in net.parameters():
    f.data.sub_(f.grad.data * learning_rate)
# Out:
# Epoch: 1
# Accuracy = tensor(47)
# Loss = tensor(0.4834, grad_fn=<AddBackward0>)
#
# Epoch: 2
# Accuracy = tensor(47)
# Loss = tensor(0.4233, grad_fn=<AddBackward0>)
#
# Epoch: 3
# Accuracy = tensor(48)
# Loss = tensor(0.3545, grad_fn=<AddBackward0>)
#
# Epoch: 4
# Accuracy = tensor(47)
# Loss = tensor(0.3158, grad_fn=<AddBackward0>)
#
# Epoch: 5
# Accuracy = tensor(44)
# Loss = tensor(0.2941, grad_fn=<AddBackward0>)
#
# Epoch: 6
# Accuracy = tensor(47)
# Loss = tensor(0.2819, grad_fn=<AddBackward0>)
#
# Epoch: 7
# Accuracy = tensor(50)
# Loss = tensor(0.2749, grad_fn=<AddBackward0>)
#
# Epoch: 8
# Accuracy = tensor(48)
# Loss = tensor(0.2707, grad_fn=<AddBackward0>)
#
# Epoch: 9
# Accuracy = tensor(47)
# Loss = tensor(0.2680, grad_fn=<AddBackward0>)
#
# Epoch: 10
# Accuracy = tensor(48)
# Loss = tensor(0.2662, grad_fn=<AddBackward0>)
#
# Epoch: 11
# Accuracy = tensor(49)
# Loss = tensor(0.2649, grad_fn=<AddBackward0>)
#
# Epoch: 12
# Accuracy = tensor(52)
# Loss = tensor(0.2638, grad_fn=<AddBackward0>)
#
# Epoch: 13
# Accuracy = tensor(52)
# Loss = tensor(0.2629, grad_fn=<AddBackward0>)
#
# Epoch: 14
# Accuracy = tensor(52)
# Loss = tensor(0.2621, grad_fn=<AddBackward0>)
#
# Epoch: 15
# Accuracy = tensor(51)
# Loss = tensor(0.2614, grad_fn=<AddBackward0>)
#
# Epoch: 16
# Accuracy = tensor(52)
# Loss = tensor(0.2607, grad_fn=<AddBackward0>)
#
# Epoch: 17
# Accuracy = tensor(52)
# Loss = tensor(0.2601, grad_fn=<AddBackward0>)
#
# Epoch: 18
# Accuracy = tensor(51)
# Loss = tensor(0.2595, grad_fn=<AddBackward0>)
#
# Epoch: 19
# Accuracy = tensor(52)
# Loss = tensor(0.2589, grad_fn=<AddBackward0>)
#
# Epoch: 20
# Accuracy = tensor(51)
# Loss = tensor(0.2583, grad_fn=<AddBackward0>)
#
# Epoch: 21
# Accuracy = tensor(51)
# Loss = tensor(0.2578, grad_fn=<AddBackward0>)
#
# Epoch: 22
# Accuracy = tensor(51)
# Loss = tensor(0.2574, grad_fn=<AddBackward0>)
#
# Epoch: 23
# Accuracy = tensor(52)
# Loss = tensor(0.2569, grad_fn=<AddBackward0>)
#
# Epoch: 24
# Accuracy = tensor(52)
# Loss = tensor(0.2565, grad_fn=<AddBackward0>)
#
# Epoch: 25
# Accuracy = tensor(53)
# Loss = tensor(0.2561, grad_fn=<AddBackward0>)
#
# Epoch: 26
# Accuracy = tensor(52)
# Loss = tensor(0.2557, grad_fn=<AddBackward0>)
#
# Epoch: 27
# Accuracy = tensor(52)
# Loss = tensor(0.2553, grad_fn=<AddBackward0>)
#
# Epoch: 28
# Accuracy = tensor(52)
# Loss = tensor(0.2549, grad_fn=<AddBackward0>)
#
# Epoch: 29
# Accuracy = tensor(52)
# Loss = tensor(0.2546, grad_fn=<AddBackward0>)
#
# Epoch: 30
# Accuracy = tensor(51)
# Loss = tensor(0.2543, grad_fn=<AddBackward0>)
#
# Epoch: 31
# Accuracy = tensor(51)
# Loss = tensor(0.2539, grad_fn=<AddBackward0>)
#
# Epoch: 32
# Accuracy = tensor(52)
# Loss = tensor(0.2536, grad_fn=<AddBackward0>)
#
# Epoch: 33
# Accuracy = tensor(52)
# Loss = tensor(0.2534, grad_fn=<AddBackward0>)
#
# Epoch: 34
# Accuracy = tensor(52)
# Loss = tensor(0.2531, grad_fn=<AddBackward0>)
#
# Epoch: 35
# Accuracy = tensor(52)
# Loss = tensor(0.2528, grad_fn=<AddBackward0>)
#
# Epoch: 36
# Accuracy = tensor(54)
# Loss = tensor(0.2525, grad_fn=<AddBackward0>)
#
# Epoch: 37
# Accuracy = tensor(54)
# Loss = tensor(0.2523, grad_fn=<AddBackward0>)
#
# Epoch: 38
# Accuracy = tensor(55)
# Loss = tensor(0.2521, grad_fn=<AddBackward0>)
#
# Epoch: 39
# Accuracy = tensor(55)
# Loss = tensor(0.2519, grad_fn=<AddBackward0>)
#
# Epoch: 40
# Accuracy = tensor(55)
# Loss = tensor(0.2517, grad_fn=<AddBackward0>)
#
# Epoch: 41
# Accuracy = tensor(55)
# Loss = tensor(0.2515, grad_fn=<AddBackward0>)
#
# Epoch: 42
# Accuracy = tensor(54)
# Loss = tensor(0.2513, grad_fn=<AddBackward0>)
#
# Epoch: 43
# Accuracy = tensor(54)
# Loss = tensor(0.2511, grad_fn=<AddBackward0>)
#
# Epoch: 44
# Accuracy = tensor(54)
# Loss = tensor(0.2509, grad_fn=<AddBackward0>)
#
# Epoch: 45
# Accuracy = tensor(53)
# Loss = tensor(0.2507, grad_fn=<AddBackward0>)
#
# Epoch: 46
# Accuracy = tensor(53)
# Loss = tensor(0.2505, grad_fn=<AddBackward0>)
#
# Epoch: 47
# Accuracy = tensor(54)
# Loss = tensor(0.2504, grad_fn=<AddBackward0>)
#
# Epoch: 48
# Accuracy = tensor(54)
# Loss = tensor(0.2502, grad_fn=<AddBackward0>)
#
# Epoch: 49
# Accuracy = tensor(54)
# Loss = tensor(0.2501, grad_fn=<AddBackward0>)
#
# Epoch: 50
# Accuracy = tensor(54)
# Loss = tensor(0.2500, grad_fn=<AddBackward0>)
#
# Epoch: 51
# Accuracy = tensor(54)
# Loss = tensor(0.2498, grad_fn=<AddBackward0>)
#
# Epoch: 52
# Accuracy = tensor(53)
# Loss = tensor(0.2497, grad_fn=<AddBackward0>)
#
# Epoch: 53
# Accuracy = tensor(53)
# Loss = tensor(0.2496, grad_fn=<AddBackward0>)
#
# Epoch: 54
# Accuracy = tensor(53)
# Loss = tensor(0.2494, grad_fn=<AddBackward0>)
#
# Epoch: 55
# Accuracy = tensor(53)
# Loss = tensor(0.2493, grad_fn=<AddBackward0>)
#
# Epoch: 56
# Accuracy = tensor(53)
# Loss = tensor(0.2492, grad_fn=<AddBackward0>)
#
# Epoch: 57
# Accuracy = tensor(53)
# Loss = tensor(0.2491, grad_fn=<AddBackward0>)
#
# Epoch: 58
# Accuracy = tensor(53)
# Loss = tensor(0.2490, grad_fn=<AddBackward0>)
#
# Epoch: 59
# Accuracy = tensor(53)
# Loss = tensor(0.2488, grad_fn=<AddBackward0>)
#
# Epoch: 60
# Accuracy = tensor(53)
# Loss = tensor(0.2487, grad_fn=<AddBackward0>)
#
# Epoch: 61
# Accuracy = tensor(53)
# Loss = tensor(0.2486, grad_fn=<AddBackward0>)
#
# Epoch: 62
# Accuracy = tensor(53)
# Loss = tensor(0.2485, grad_fn=<AddBackward0>)
#
# Epoch: 63
# Accuracy = tensor(53)
# Loss = tensor(0.2484, grad_fn=<AddBackward0>)
#
# Epoch: 64
# Accuracy = tensor(53)
# Loss = tensor(0.2483, grad_fn=<AddBackward0>)
#
# Epoch: 65
# Accuracy = tensor(54)
# Loss = tensor(0.2482, grad_fn=<AddBackward0>)
#
# Epoch: 66
# Accuracy = tensor(54)
# Loss = tensor(0.2482, grad_fn=<AddBackward0>)
#
# Epoch: 67
# Accuracy = tensor(54)
# Loss = tensor(0.2481, grad_fn=<AddBackward0>)
#
# Epoch: 68
# Accuracy = tensor(54)
# Loss = tensor(0.2480, grad_fn=<AddBackward0>)
#
# Epoch: 69
# Accuracy = tensor(53)
# Loss = tensor(0.2479, grad_fn=<AddBackward0>)
#
# Epoch: 70
# Accuracy = tensor(54)
# Loss = tensor(0.2478, grad_fn=<AddBackward0>)
#
# Epoch: 71
# Accuracy = tensor(54)
# Loss = tensor(0.2477, grad_fn=<AddBackward0>)
#
# Epoch: 72
# Accuracy = tensor(54)
# Loss = tensor(0.2476, grad_fn=<AddBackward0>)
#
# Epoch: 73
# Accuracy = tensor(54)
# Loss = tensor(0.2476, grad_fn=<AddBackward0>)
#
# Epoch: 74
# Accuracy = tensor(55)
# Loss = tensor(0.2475, grad_fn=<AddBackward0>)
#
# Epoch: 75
# Accuracy = tensor(55)
# Loss = tensor(0.2474, grad_fn=<AddBackward0>)
#
# Epoch: 76
# Accuracy = tensor(55)
# Loss = tensor(0.2474, grad_fn=<AddBackward0>)
#
# Epoch: 77
# Accuracy = tensor(55)
# Loss = tensor(0.2473, grad_fn=<AddBackward0>)
#
# Epoch: 78
# Accuracy = tensor(55)
# Loss = tensor(0.2472, grad_fn=<AddBackward0>)
#
# Epoch: 79
# Accuracy = tensor(55)
# Loss = tensor(0.2472, grad_fn=<AddBackward0>)
#
# Epoch: 80
# Accuracy = tensor(55)
# Loss = tensor(0.2471, grad_fn=<AddBackward0>)
#
# Epoch: 81
# Accuracy = tensor(55)
# Loss = tensor(0.2470, grad_fn=<AddBackward0>)
#
# Epoch: 82
# Accuracy = tensor(56)
# Loss = tensor(0.2470, grad_fn=<AddBackward0>)
#
# Epoch: 83
# Accuracy = tensor(56)
# Loss = tensor(0.2469, grad_fn=<AddBackward0>)
#
# Epoch: 84
# Accuracy = tensor(56)
# Loss = tensor(0.2468, grad_fn=<AddBackward0>)
#
# Epoch: 85
# Accuracy = tensor(56)
# Loss = tensor(0.2468, grad_fn=<AddBackward0>)
#
# Epoch: 86
# Accuracy = tensor(56)
# Loss = tensor(0.2467, grad_fn=<AddBackward0>)
#
# Epoch: 87
# Accuracy = tensor(56)
# Loss = tensor(0.2466, grad_fn=<AddBackward0>)
#
# Epoch: 88
# Accuracy = tensor(56)
# Loss = tensor(0.2466, grad_fn=<AddBackward0>)
#
# Epoch: 89
# Accuracy = tensor(56)
# Loss = tensor(0.2465, grad_fn=<AddBackward0>)
#
# Epoch: 90
# Accuracy = tensor(56)
# Loss = tensor(0.2464, grad_fn=<AddBackward0>)
#
# Epoch: 91
# Accuracy = tensor(56)
# Loss = tensor(0.2464, grad_fn=<AddBackward0>)
#
# Epoch: 92
# Accuracy = tensor(56)
# Loss = tensor(0.2463, grad_fn=<AddBackward0>)
#
# Epoch: 93
# Accuracy = tensor(56)
# Loss = tensor(0.2463, grad_fn=<AddBackward0>)
#
# Epoch: 94
# Accuracy = tensor(55)
# Loss = tensor(0.2462, grad_fn=<AddBackward0>)
#
# Epoch: 95
# Accuracy = tensor(55)
# Loss = tensor(0.2461, grad_fn=<AddBackward0>)
#
# Epoch: 96
# Accuracy = tensor(56)
# Loss = tensor(0.2461, grad_fn=<AddBackward0>)
#
# Epoch: 97
# Accuracy = tensor(56)
# Loss = tensor(0.2460, grad_fn=<AddBackward0>)
#
# Epoch: 98
# Accuracy = tensor(56)
# Loss = tensor(0.2460, grad_fn=<AddBackward0>)
#
# Epoch: 99
# Accuracy = tensor(56)
# Loss = tensor(0.2459, grad_fn=<AddBackward0>)
#
# Epoch: 100
# Accuracy = tensor(56)
# Loss = tensor(0.2458, grad_fn=<AddBackward0>)
