# %% [markdown]
# ### **Introduction to Python: Lesson 1**

# %% [markdown]
# **Features of Python:**
# 1. Simple
# 2. Easy to Learn
# 3. Free and Open Source
# 4. High-level Language

# %%
7 + 8
# Out:
# 15

# %%
5 - 2
# Out:
# 3

# %%
4 * 5
# Out:
# 20

# %%
18 / 4
# Out:
# 4.5

# %%
18 // 4
# Out:
# 4

# %%
18 % 4
# Out:
# 2

# %%
5 ** 3
# Out:
# 125
